# %%
"""
предустановки игры:
разерешение 1600*1900 (125%)
нахождение:правый верхний угол
2222,980 / 3840,760
region=(2222,60,3840,980)
лево верх = 2200,50,500,450
лево низ = 2200,500,500,400
сред верх = 2900,330,150,300
сред низ = 2900,600,200,350



"""
import pyautogui    #работа с картинками
import time         #таймеры
import win32api     #для управления мышью, pyautohui не всегда срабатывает клик
import win32con     #для управления мышью, pyautohui не всегда срабатывает клик
import win32com.client     #для управления нажатием HOME
import pyttsx3      #звук
import os           #переход в спящий режим
import pytesseract as tess  #расознование текста
tess.pytesseract.tesseract_cmd  = r'C:\Program Files\Tesseract-OCR\tesseract.exe' #расознование текста
#tess.pytesseract.tesseract_cmd  = r'C:\Program Files\Tesseract-OCR\4.0-with-LSTM\tesseract.exe'
from PIL import Image #расознование текста
import re          #парсинг цен
import pyperclip   #работа с буфером
import random      #рандом

""" Change_price
функция изменеия стоимости.
работает при открытом окне "торговая система"
В секторе "Продавцы"(Торговая система) находим цена, которая есть на расстоянии "Станция".
Если строка "Станция" не имеет синего фона - то продолжать, иначе конец функции
переводим в цифру сумму в столбике "Цена" 
в окне "заказы в торговой системе"
выделяем изначальный товара в "продажа"(заказы в торговой система)  - повой мышкой -
изменить ордер 
ввод текста (пока не понятно как, или через буфер обмена, или по цифрам)
"""


def pause_random(x):
    time.sleep(random.uniform(x,x*2))

def click(x,y,t): # просто клик мышки по координатам ЛЕВОЙ
    print("click")
    win32api.SetCursorPos((x,y))
    time.sleep(0.1)
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTDOWN,x,y,0,0)
    time.sleep(t)
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTUP,x,y,0,0)
    
def click_R(x,y,t): #  клик мышки по координатам ПРАВОЙ кнопкой
    print("click_R")
    win32api.SetCursorPos((x,y))
    time.sleep(0.1)
    win32api.mouse_event(win32con.MOUSEEVENTF_RIGHTDOWN,x,y,0,0)
    time.sleep(t)
    win32api.mouse_event(win32con.MOUSEEVENTF_RIGHTUP,x,y,0,0)

def LUP(): #выход на 1 позицию
    print("LUP")
    print("поиск продажа")
    #Проверяем наличие вкладки"Торговая система"
    pict = pyautogui.locateOnScreen('prodazha.png', confidence=0.9,region=(2222,60,3840,980)) #без левого столба "заказы в торг сист"
    if pict==None:
        print("не найдена картинка Торговая система")
    else:
        pause_random(0.3)
        x,y=pyautogui.center(pict)
        y=y+100
        click(x,y,0.1)
        pause_random(0.3)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{HOME}")
        
def B_LUP(): #выход на 1 позицию
    print("B_LUP")
    print("поиск покупка")
    #Проверяем наличие вкладки"Торговая система"
    pict = pyautogui.locateOnScreen('pokupka.png', confidence=0.9,region=(2200,50,1000,1000)) #без левого столба "заказы в торг сист"
    if pict==None:
        print("не найдена картинка Покупка")
    else:
        pause_random(0.3)
        x,y=pyautogui.center(pict)
        y=y+100
        click(x,y,0.1)
        pause_random(0.3)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{HOME}")
        
def menu_prodazha():
    print("menu_prodazha")
    pict = pyautogui.locateOnScreen('i.png', confidence=0.9,region=(2200,50,500,450))
    if pict==None:
        print("не найдена картинка i")
    else:
        pause_random(0.2)
        x,y=pyautogui.center(pict)
        x=x-50
        click(x,y,0.1)
        click(x,y,0.1) #двойной клик по позиции слева
        analiz_cen(x,y) #возврат координат левый столб
        
def B_menu_prodazha():
    print("B_menu_prodazha")
    pict = pyautogui.locateOnScreen('i.png', confidence=0.9,region=(2200,500,500,400))
    if pict==None:
        print("не найдена картинка i")
    else:
        pause_random(0.1)
        x,y=pyautogui.center(pict)
        x=x-50
        click(x,y,0.1)
        time.sleep(0.2)
        click(x,y,0.1)
        click(x,y,0.1) #тройной клик по позиции слева
        B_analiz_cen(x,y) #возврат координат левый столб
    
def menu_prodazha_blue():
    print("menu_prodazha_blue")
    pause_random(0.4)
    pict = pyautogui.locateOnScreen('i_blue.png', confidence=0.99,region=(2200,50,500,450))
    if pict==None:
        print("не найдена картинка i_blue")
    else:
        pause_random(0.1)
        x,y=pyautogui.center(pict)
        x=x-50
        y=y+10
        click(x,y,0.1)
        time.sleep(0.2)
        click(x,y,0.1)
        click(x,y,0.1) #тройной клик по позиции слева
        analiz_cen(x,y)
        
def B_menu_prodazha_blue():
    print("menu_prodazha_blue")
    pause_random(0.4)
    pict = pyautogui.locateOnScreen('i_blue.png', confidence=0.99,region=(2200,500,500,400))
    if pict==None:
        print("не найдена картинка i_blue")
    else:
        pause_random(0.1)
        x,y=pyautogui.center(pict)
        x=x-50
        y=y+10
        click(x,y,0.1)
        click(x,y,0.1)
        time.sleep(0.1)
        click(x,y,0.1) #тройной клик по позиции слева
        B_analiz_cen(x,y)
    
def analiz_cen(x,y):
    print("analiz_cen")
    pause_random(0.9)       
    pict = pyautogui.locateOnScreen('Stancia_blue_black.png', confidence=0.99,region=(2850,330,150,300))
    pict2 = pyautogui.locateOnScreen('Stancia_blue.png', confidence=0.99,region=(2850,330,150,300))
    if pict!=None or (pict==None and pict2==None):    #если синяя на 2 месте или вообще нет
        print('меняем цену:')
        pict = pyautogui.locateOnScreen('Stancia_black.png', confidence=0.9,region=(2850,330,150,300)) #сред низ
        if pict==None:
            print("Stancia_black не найдена")
        else:
            x1,y1=pyautogui.center(pict)
            pause_random(0.3)
            click(x1,y1,0.2)
            time.sleep(0.5)
            win32api.keybd_event (win32con.VK_LCONTROL,1)
            time.sleep(0.3)
            shell = win32com.client.Dispatch("WScript.Shell")
            time.sleep(0.3)
            shell.SendKeys("{C}")
            pause_random(0.4)
            shell.SendKeys("^")
            pause_random(0.2)
            shell.SendKeys("^")
            pause_random(0.2)
            text=pyperclip.paste()
            pause_random(0.3)
            print ("цена скопирована")
            text = re.sub(r'Станция	','', text)
            text = text.replace(u'\xa0', u' ')
            text = re.sub(r' ','', text)
            text = re.sub(r'[xa]','', text)
            print (text)
            text = re.sub(r'ISK[^`]{,1000}','', text)
            #конвертация с проверкой
            try:
                a=float(text)
            except ValueError:
                print('Ошибка. скопирован текст')
                a=0
            else:         
                time.sleep(0.1)
                a=a-0.01
                print(a)   # минимальная цена продажи (FLOAT)      - определиться или буфер или переменная!!!
                pyperclip.copy (a)
                change_price(x,y)
    else:
        print("Изменение цен не требуется")
        click(x,y,0.1)
        
def B_analiz_cen(x,y):
    print("B_analiz_cen")
    pause_random(0.9)
    pict = pyautogui.locateOnScreen('Stancia_green_black.png', confidence=0.99,region=(2850,600,200,350)) 
    if pict==None:
        print("Изменение цен не требуется")
        click(x,y,0.1)
    else:  
        print('изменение цен требуется:')
        pict = pyautogui.locateOnScreen('Stancia_green.png', confidence=0.9,region=(2850,600,200,350))
        if pict==None:
            print("Stancia_green не найдена")
        else:
            x1,y1=pyautogui.center(pict)
            pause_random(0.3)
            click(x1,y1,0.2)
            time.sleep(0.5)
            win32api.keybd_event (win32con.VK_LCONTROL,1)
            time.sleep(0.3)
            shell = win32com.client.Dispatch("WScript.Shell")
            time.sleep(0.3)
            shell.SendKeys("{C}")
            pause_random(0.4)
            shell.SendKeys("^")
            pause_random(0.2)
            shell.SendKeys("^")
            pause_random(0.2)
            text=pyperclip.paste()
            pause_random(0.3)
            print ("цена скопирована")
            text = re.sub(r'Станция	','', text)
            text = text.replace(u'\xa0', u' ')
            text = re.sub(r' ','', text)
            text = re.sub(r'[xa]','', text)
            print (text)
            text = re.sub(r'ISK[^`]{,1000}','', text)
            #конвертация с проверкой
            try:
                a=float(text)
            except ValueError:
                print('Ошибка. скопирован текст')
                a=0
            else:         
                time.sleep(0.1)
                a=a+0.011
                print(a)   # минимальная цена продажи (FLOAT)      - определиться или буфер или переменная!!!
                pyperclip.copy (a)
                B_change_price(x,y)

def change_price(x,y):
    print("change_price")
    pause_random(0.2)
    click_R(x,y,0.2)
    time.sleep(0.3)
    pict = pyautogui.locateOnScreen('izmenit_order.png', confidence=0.9,region=(2200,50,800,600)) #без левого
    if pict==None:
        print("ОШИБКА! не найдена картинка измененить ордер")
    else:
        pause_random(0.1)
        click (x+20,y+15,0.2) #в подменю "изменить цену"
        #прожимаем Del
        win32api.keybd_event (win32con.VK_LCONTROL,1)
        pause_random(0.3)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{V}")
        pause_random(0.3)
        shell.SendKeys("^")
        pause_random(0.3)
        shell.SendKeys("{ENTER}")
        pause_random(0.3)
        pict = pyautogui.locateOnScreen('da.png', confidence=0.9,region=(2222,60,1000,1000))
        if pict:
            x1,y1=pyautogui.center(pict)
            time.sleep(0.5)
            click(x1,y1,0.2)
        else:
            print("не найдена ДА")
            
def B_change_price(x,y):
    print("B_hange_price")
    pause_random(0.2)
    click_R(x,y,0.2)
    time.sleep(0.3)
    pict = pyautogui.locateOnScreen('izmenit_order.png', confidence=0.9,region=(2200,500,700,400)) #без левого
    if pict==None:
        print("ОШИБКА! не найдена картинка измененить ордер")   
    else:
        pause_random(0.1)
        x1,y1=pyautogui.center(pict)
        click (x1,y1,0.2) #в подменю "изменить цену"
        #прожимаем Del
        win32api.keybd_event (win32con.VK_LCONTROL,1)
        pause_random(0.3)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{V}")
        pause_random(0.3)
        shell.SendKeys("^")
        pause_random(0.3)
        shell.SendKeys("{ENTER}")
        pause_random(0.3)
        pict = pyautogui.locateOnScreen('da.png', confidence=0.9,region=(2222,60,1000,1000))
        if pict:
            x1,y1=pyautogui.center(pict)
            time.sleep(0.5)
            click(x1,y1,0.2)
        else:
            print("не найдена ДА")

def run():
    print("Start_SELL >>>>>>>>>>>>>>>>>>>")
    i=0
    pause_random(0.5)
    pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.9,region=(2200,50,500,500))
    LUP()
    while pict==None: 
        pause_random(0.1)
        print('Новый цикл ====')
        if i==0:
            menu_prodazha()
        else:
            menu_prodazha_blue()
        i=+1
        pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.9,region=(2200,50,500,500))
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{DOWN}")
    pause_random(0.2)    
    shell = win32com.client.Dispatch("WScript.Shell")
    shell.SendKeys("{HOME}")

def B_run():
    print("Start_BUY >>>>>>>>>>>>>>>>>>>")
    i=0
    pause_random(0.5)
    pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.95,region=(2200,600,500,400)) #лев низ
    B_LUP()
    while pict==None: 
        print('Новый цикл ====')
        pause_random(0.1)
        if i==0:
            B_menu_prodazha()
        else:
            B_menu_prodazha_blue()
        i=+1
        pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.95,region=(2200,600,500,400)) #лев низ
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{DOWN}")
    pause_random(0.2)    
    shell = win32com.client.Dispatch("WScript.Shell")
    shell.SendKeys("{HOME}")


i=0    
for i in range(0,100):   
    print ("новый цикл ================================= ",i)
    run()
    B_run()
    #pause_random(100)
print("END")
# Out:
# новый цикл =================================  0
# Start_SELL >>>>>>>>>>>>>>>>>>>
# LUP
# поиск продажа
# click
# Новый цикл ====
# menu_prodazha
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 106599996.10ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д23ч54мин47с
# 106599996.08999999
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 87979993.99ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д23ч59мин58с
# 87979993.97999999
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 73987243.03ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д23ч56мин23с
# 73987243.02
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 39880000.00ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д23ч54мин46с
# 39879999.99
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 21699995.98ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д21ч25мин24с
# 21699995.97
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 21555554.00ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д23ч27мин18с
# 21555553.99
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 16999999.58ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д20ч9мин59с
# 16999999.569999997
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 10999998.98ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д22ч43мин14с
# 10999998.97
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 9898986.91ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д22ч37мин30с
# 9898986.9
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 6388985.98ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д21ч27мин54с
# 6388985.970000001
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 5443991.87ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	29д23ч48мин42с
# 5443991.86
# change_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# analiz_cen
# меняем цену:
# click
# цена скопирована
# 467436.99ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	89д22ч55мин24с
# 467436.98
# change_price
# click_R
# click
# не найдена ДА
# Start_BUY >>>>>>>>>>>>>>>>>>>
# B_LUP
# поиск покупка
# click
# Новый цикл ====
# B_menu_prodazha
# click
# click
# click
# B_analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# изменение цен требуется:
# click
# цена скопирована
# 90578776.17ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	1	2д22ч22мин43с
# 90578776.18100001
# B_hange_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# Изменение цен не требуется
# click
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# изменение цен требуется:
# click
# цена скопирована
# 85000002.50ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	1	22ч19мин3с
# 85000002.511
# B_hange_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# изменение цен требуется:
# click
# цена скопирована
# 80005010.61ISK	JitIV-Moon4-СборочныйкомплексCldriNvy	1	89д22ч4мин17с
# 80005010.621
# B_hange_price
# click_R
# click
# не найдена ДА
# Новый цикл ====
# menu_prodazha_blue
# не найдена картинка i_blue
# Новый цикл ====
# menu_prodazha_blue
# click
# click
# click
# B_analiz_cen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-53c985b8f86b> in <module>
#     359     print ("новый цикл ================================= ",i)
#     360     run()
# --> 361     B_run()
#     362     #pause_random(100)
#     363 print("END")
#
# <ipython-input-47-53c985b8f86b> in B_run()
#     345             B_menu_prodazha()
#     346         else:
# --> 347             B_menu_prodazha_blue()
#     348         i=+1
#     349         pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.95,region=(2200,600,500,400)) #лев низ
#
# <ipython-input-47-53c985b8f86b> in B_menu_prodazha_blue()
#     152         time.sleep(0.1)
#     153         click(x,y,0.1) #тройной клик по позиции слева
# --> 154         B_analiz_cen(x,y)
#     155
#     156 def analiz_cen(x,y):
#
# <ipython-input-47-53c985b8f86b> in B_analiz_cen(x, y)
#     206 def B_analiz_cen(x,y):
#     207     print("B_analiz_cen")
# --> 208     pause_random(0.9)
#     209     pict = pyautogui.locateOnScreen('Stancia_green_black.png', confidence=0.99,region=(2850,600,200,350))
#     210     if pict==None:
#
# <ipython-input-47-53c985b8f86b> in pause_random(x)
#      42
#      43 def pause_random(x):
# ---> 44     time.sleep(random.uniform(x,x*2))
#      45
#      46 def click(x,y,t): # просто клик мышки по координатам ЛЕВОЙ
#
# KeyboardInterrupt:

# %%
Станция	30 100 015.86 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	89д 23ч 46мин 19с

Станция	1	160 995 554.98 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	89д 23ч 54мин 39с
Станция	30 100 015.85 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	89д 22ч 43мин 26с
Станция	25 000 416.84 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	29д 23ч 45мин 44с
Станция	25 000 416.81 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	89д 23ч 7мин 35с
Станция	25 000 416.80 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	29д 23ч 7мин 19с
Станция	25 000 416.71 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	2д 22ч 9мин 39с
Станция	25 000 416.26 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	18ч 7мин
Станция	25 000 416.20 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	89д 17ч 9мин 29с
Станция	25 000 413.63 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	87д 15ч 11мин 48с
Osprey	1/20	4 851 250.76 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	The Forge	Станция	1	89д 18ч 4мин 29с
Станция	4 851 250.91 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	89д 23ч 36мин 13с
Capital Solace Scoped Remote Armor Repairer	2/2	30 100 015.85 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	The Forge	Станция	1	89д 22ч 43мин 27с
Станция	4 851 250.90 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	89д 23ч 2мин 5с
Станция	4 851 250.77 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	89д 23ч 4мин 21с
Станция	4 851 239.97 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	88д 15ч 48мин 20с
Станция	4 851 220.00 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	88д 6ч 14мин 6с
Limited Jump Drive Economizer	2/2	5 250 000.24 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	The Forge	Станция	1	89д 22ч 5мин 41с
print("analiz_cen")
time.sleep(1)
pict = pyautogui.locateOnScreen('Stancia_blue.png', confidence=0.99,region=(2222,60,1000,980)) 
if pict==None:
    print("Изменение цен не требуется")
else:
    print ("требуется")
# Out:
#   File "<ipython-input-24-aac190b57b36>", line 1
#     Станция	30 100 015.86 ISK	Jita IV - Moon 4 - Сборочный комплекс Caldari Navy	Станция	1	89д 23ч 46мин 19с
#            	 ^
# SyntaxError: invalid syntax

# %%
text= input()
try:
    a=float(text)
except ValueError:
    print('Это не число. Выходим.')
    a=0
else:
    a=a*2

print(a)
# Out:
# sdfwer
# Это не число. Выходим.
# 0

# %%
time.sleep(1)
pict = pyautogui.locateOnScreen('Stancia_blue_black.png', confidence=0.99,region=(2850,330,150,300))
pict2 = pyautogui.locateOnScreen('Stancia_blue.png', confidence=0.99,region=(2850,330,150,300))
if pict!=None or (pict==None and pict2==None):
    print("меняем")
else:
    print('все хорошо')
print(type(pict))
print(type(pict2))
# Out:
# все хорошо
# <class 'NoneType'>
# <class 'pyscreeze.Box'>

# %%
import random
print(random.uniform(0.5, 1))
pause_random
# Out:
# 0.5549960141097745
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-ae5c8cd4c8bd> in <module>
#       1 import random
#       2 print(random.uniform(0.5, 1))
# ----> 3 pause
#
# NameError: name 'pause' is not defined

# %%
#буфер обмена
>>> import pyperclip
>>> pyperclip.copy('The text to be copied to the clipboard.')
>>> pyperclip.paste()
# Out:
# 'The text to be copied to the clipboard.'

# %%
#
import pytesseract #расознование текста
C:\Program Files\Tesseract-OCR
from PIL import Image
from pytesseract import image_to_string
#k=pytesseract.image_to_string('1.png')
#print(k)
print pytesseract.image_to_string(Image.open('1.png'))

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

def ocr_core(filename):
    """
    This function will handle the core OCR processing of images.
    """
    text = pytesseract.image_to_string(Image.open(filename))  # We'll use Pillow's Image class to open the image and pytesseract to detect the string in the image
    return text

print(ocr_core('2.png'))

# %%
import pytesseract as tess
tess.pytesseract.tesseract_cmd  = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
from PIL import Image

img = Image.open('11.png')
text = tess.image_to_string(img)
print(text)
