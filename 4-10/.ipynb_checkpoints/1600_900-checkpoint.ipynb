# %%
"""
предустановки игры:
разерешение 1600*1900 (125%)
нахождение:правый верхний угол
2222,980 / 3840,760
обзорная панель ПВЕ (гайки, мобы, станции)
region=(2222,60,3840,980)
лево верх = 2200,50,500,450
лево низ = 2200,500,500,400
сред верх = 2900,330,150,300
сред низ = 2900,600,200,350



"""
import pyautogui    #работа с картинками
import time         #таймеры
import win32api     #для управления мышью, pyautohui не всегда срабатывает клик
import win32con     #для управления мышью, pyautohui не всегда срабатывает клик
import win32com.client     #для управления нажатием HOME
import pyttsx3      #звук
import os           #переход в спящий режим
import pytesseract as tess  #расознование текста
tess.pytesseract.tesseract_cmd  = r'C:\Program Files\Tesseract-OCR\tesseract.exe' #расознование текста
#tess.pytesseract.tesseract_cmd  = r'C:\Program Files\Tesseract-OCR\4.0-with-LSTM\tesseract.exe'
from PIL import Image #расознование текста
import re          #парсинг цен
import pyperclip   #работа с буфером
import random      #рандом
import pyttsx3      #звук
engine = pyttsx3.init() #звук

def click(x,y,t): # просто клик мышки по координатам ЛЕВОЙ
    print("click")
    win32api.SetCursorPos((x,y))
    time.sleep(0.1)
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTDOWN,x,y,0,0)
    time.sleep(t)
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTUP,x,y,0,0)
    
def click_R(x,y,t): #  клик мышки по координатам ПРАВОЙ кнопкой
    print("click_R")
    win32api.SetCursorPos((x,y))
    time.sleep(0.1)
    win32api.mouse_event(win32con.MOUSEEVENTF_RIGHTDOWN,x,y,0,0)
    time.sleep(t)
    win32api.mouse_event(win32con.MOUSEEVENTF_RIGHTUP,x,y,0,0)

def pause_random(x):
    time.sleep(random.uniform(x*1.1,x*2))

def search_gurista(i):
    print("search_gurista")
    pict = pyautogui.locateOnScreen('gurista.png', confidence=0.95,region=(2200,50,500,900))
    if pict!=None:
        x,y=pyautogui.center(pict)
        click_R(x,y,0.1)
        pause_random(0.5)
        x=x+50
        y=y+10
        click(x,y,0.1)
    else:
        print("Не найден gurirsta")
        Smena_lokacii(i)
        
def Smena_lokacii(i):
    print("Smena_lokacii-",i)
    a=["aak.png","yla.png","iss.png"]
    pict = pyautogui.locateOnScreen(a[i%3], confidence=0.9,region=(2200,50,1600,900))
    pause_random(0.5)
    if pict!=None:
        print("варпаем на ",a[i%3])
        x,y=pyautogui.center(pict)
        click_R(x,y,0.1)
        pause_random(0.8)
        pict = pyautogui.locateOnScreen("sovershit_prizhok.png", confidence=0.9,region=(2200,50,1600,900))
        if pict!=None:
            x,y=pyautogui.center(pict)
            click(x,y,0.1)
            time.sleep(50)
            print("ждем переварпа. проверяем обзорку")
            x1 = pyautogui.screenshot(region=(3580,250,100,100))     
            time.sleep(2)
            x2 = pyautogui.screenshot(region=(3580,250,100,100))
            schet_varp = 0    
            while x1==x2 and x<20:   #не работает!!!!!!!!
                x1 = pyautogui.screenshot(region=(3580,250,100,100))     
                time.sleep(2)
                x2 = pyautogui.screenshot(region=(3580,250,100,100))
                schet_varp+=1
        
        
def varp():
    print("varp")
    time.sleep(8)
    pict = pyautogui.locateOnScreen('varp.png', confidence=0.9,region=(2200,50,1600,900))
    while pict!=None:
        pict = pyautogui.locateOnScreen('varp.png', confidence=0.9,region=(2200,50,1600,900))
        time.sleep(1)
    else: 
        print('конец варп')
        time.sleep(3)
        
def udalenie_hound():
    print("udalenie_hound")
    pict = pyautogui.locateOnScreen('hound.png', confidence=0.9,region=(2200,50,1600,900))
    if pict!=None:
        x,y=pyautogui.center(pict)
        click_R(x,y,0.1)
        time.sleep(0.5)
        pict = pyautogui.locateOnScreen('ignor.png', confidence=0.9,region=(2200,50,1600,900))
        if pict!=None:
            x,y=pyautogui.center(pict)
            click(x,y,0.1)
            print("hound удален")
    else:
        print("hound не обнаружен")
        
def search_mob():
    x=0
    print("search_mob")
    pict = pyautogui.locateOnScreen('mob_1.png', confidence=0.9,region=(2200,50,1600,900))
    if pict!=None:
        x,y=pyautogui.center(pict)
    else:
        pict = pyautogui.locateOnScreen('mob_2.png', confidence=0.9,region=(2200,50,1600,900))
        if pict!=None:
            x,y=pyautogui.center(pict)
        else:
            pict = pyautogui.locateOnScreen('mob_3.png', confidence=0.9,region=(2200,50,1600,900))
            if pict!=None:
                x,y=pyautogui.center(pict)
    if x>0:
        click_R(x,y,0.1)
        pause_random(0.7)
        x=x+50
        y=y+10
        click(x,y,0.1)         
    
#def ozhidanie_guristas(i):
#    nomer_proverki=0
#    print("ozhidanie_guristas")
#    time.sleep(3)
#    pict = None
#    while pict==None and nomer_proverki<3:
#        pict = pyautogui.locateOnScreen('gurista.png', confidence=0.95,region=(2200,50,500,900))
#        if pict==None:
#            print('ждем гуристас nomer_proverki=',nomer_proverki)
#            nomer_proverki+=1
#            time.sleep(2)
#            if nomer_proverki >2:
#                Smena_lokacii(i)
#    else: 
#        print('найдена гуристас')

def f1():
    print('F1')
    shell = win32com.client.Dispatch("WScript.Shell")
    shell.SendKeys("{F1}")  
    
def attack():
    print("attack")
    pause_random(1)
    pict = pyautogui.locateOnScreen('blokirovka_red.png', confidence=0.9,region=(2200,50,1600,900))
    if pict!=None:
        x,y=pyautogui.center(pict)
        x1 = pyautogui.screenshot(region=(x+220,y+25,40,10))     #x - оружие
        y1 = pyautogui.screenshot(region=(x+10,y+90,15,15))      #y - хил
        time.sleep(2)
        x2 = pyautogui.screenshot(region=(x+220,y+25,40,10))
        y2 = pyautogui.screenshot(region=(x+10,y+90,15,15))
        a=0
        while x1!=x2 and y1==y2:      #пока изменяется оружие и не меняется хил
            a+=1
            print("attack.цикл=",a)
            x1 = pyautogui.screenshot(region=(x+220,y+25,40,10))
            y1 = pyautogui.screenshot(region=(x+10,y+90,15,15))
            time.sleep(2)
            x2 = pyautogui.screenshot(region=(x+220,y+25,40,10))
            y2 = pyautogui.screenshot(region=(x+10,y+90,15,15))
        else:
            print("rabota_oruzhiya - stop")
            return("stop")
    else:
        print("блокировка не найдена")
        
def Idet_boi():
    print("Idet_boi")
    pause_random(0.3)
    f1()
    boi=1
    while boi<40:
        print("idet_boi=",boi)
        boi+=1 
        pict = pyautogui.locateOnScreen('mob_1.png', confidence=0.9,region=(3200,50,600,900))
        if pict==None:
            print("mob1=нет")
            pict = pyautogui.locateOnScreen('mob_2.png', confidence=0.9,region=(3200,50,600,900))
            if pict==None:
                print("mob2=нет")
                pict = pyautogui.locateOnScreen('mob_3.png', confidence=0.9,region=(3200,50,600,900))
                if pict==None:
                    pause_random(1)
                    print("mob3=нет")
                       # pict2 = pyautogui.locateOnScreen('recharge_full.png', confidence=0.95,region=(2200,50,1600,900))
                       # if pict2!=None:
                       #     pause_random(0.8)
                    boi=40 
        #проверка работы оружия
        if attack()=="stop":
            pause_random(0.1)
            f1()
        #проверка здоровья
        pict = pyautogui.locateOnScreen('shield_kontrol.png', confidence=0.9,region=(2200,50,1600,900))
        if pict==None:
            print("отварп на Safe_buka")
            #отварп на станцию и стоянка минуту
            pict = pyautogui.locateOnScreen('safe_buka.png', confidence=0.9,region=(2200,50,1600,900))
            if pict!=None:
                print("safe_buka.png")
                x,y=pyautogui.center(pict)
                click_R(x,y,0.1)
                x=x+50
                y=y+10
                pause_random(0.8)
                click(x,y,0.1) 
                pause_random(60)
            else:
                print(" нет сейф-буки!")
                pict = pyautogui.locateOnScreen('pve.png', confidence=0.9,region=(2200,50,1600,900))
                if pict!=None:
                    print("pve.png")
                    x,y=pyautogui.center(pict)
                    click(x,y,0.1) 
   
def RUN(i):
    print("RUN")
    time.sleep(3)
 #   ozhidanie_guristas(i)
    udalenie_hound()
    pause_random(0.8)
    search_gurista(i)
    varp()
    search_mob()
    pause_random(0.8)
    Idet_boi()

i=0
while i<500:
    time.sleep(1)
    print("новый цикл",i)
    i+=1
    RUN(i)
# Out:
# новый цикл 0
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 3
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# rabota_oruzhiya - stop
# F1
# idet_boi= 4
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 5
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 6
# mob1=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# rabota_oruzhiya - stop
# F1
# idet_boi= 7
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 1
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 3
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 4
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# rabota_oruzhiya - stop
# F1
# idet_boi= 5
# attack
# attack.цикл= 1
# attack.цикл= 2
# rabota_oruzhiya - stop
# F1
# idet_boi= 6
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# отварп на Safe_buka
#  нет сейф-буки!
# idet_boi= 7
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# rabota_oruzhiya - stop
# F1
# новый цикл 2
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# rabota_oruzhiya - stop
# F1
# idet_boi= 3
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 4
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 5
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 6
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 7
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 8
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 9
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 10
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 11
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 12
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 13
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 14
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 15
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 16
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# rabota_oruzhiya - stop
# F1
# idet_boi= 17
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# rabota_oruzhiya - stop
# F1
# idet_boi= 18
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 19
# mob1=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# rabota_oruzhiya - stop
# F1
# idet_boi= 20
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# отварп на Safe_buka
# safe_buka.png
# click_R
# click
# idet_boi= 21
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# rabota_oruzhiya - stop
# F1
# idet_boi= 22
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 23
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 24
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 3
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# Idet_boi
# F1
# idet_boi= 1
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 4
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# mob1=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 3
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# отварп на Safe_buka
#  нет сейф-буки!
# pve.png
# click
# idet_boi= 4
# mob1=нет
# attack
# блокировка не найдена
# отварп на Safe_buka
#  нет сейф-буки!
# pve.png
# click
# idet_boi= 5
# mob1=нет
# attack
# блокировка не найдена
# idet_boi= 6
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 7
# mob1=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# rabota_oruzhiya - stop
# F1
# idet_boi= 8
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 9
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# rabota_oruzhiya - stop
# F1
# idet_boi= 10
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# rabota_oruzhiya - stop
# F1
# idet_boi= 11
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 12
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 13
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 14
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 15
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 16
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 17
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# rabota_oruzhiya - stop
# F1
# idet_boi= 18
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 19
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 20
# mob1=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 21
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 22
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 23
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 24
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 25
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 26
# mob1=нет
# mob2=нет
# attack
# блокировка не найдена
# idet_boi= 27
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 28
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# rabota_oruzhiya - stop
# F1
# idet_boi= 29
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# rabota_oruzhiya - stop
# F1
# idet_boi= 30
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 31
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 32
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 33
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# rabota_oruzhiya - stop
# F1
# idet_boi= 34
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 35
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# rabota_oruzhiya - stop
# F1
# idet_boi= 36
# mob1=нет
# mob2=нет
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 37
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# rabota_oruzhiya - stop
# F1
# idet_boi= 38
# mob1=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# rabota_oruzhiya - stop
# F1
# idet_boi= 39
# mob1=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# attack.цикл= 36
# attack.цикл= 37
# attack.цикл= 38
# attack.цикл= 39
# attack.цикл= 40
# attack.цикл= 41
# attack.цикл= 42
# attack.цикл= 43
# attack.цикл= 44
# attack.цикл= 45
# attack.цикл= 46
# rabota_oruzhiya - stop
# F1
# новый цикл 5
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 3
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# rabota_oruzhiya - stop
# F1
# idet_boi= 4
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 5
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# rabota_oruzhiya - stop
# F1
# idet_boi= 6
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 6
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# mob1=нет
# mob2=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 7
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# Не найден gurirsta
# Smena_lokacii- 8
# varp
# конец варп
# search_mob
# Idet_boi
# F1
# idet_boi= 1
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 8
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# Не найден gurirsta
# Smena_lokacii- 9
# varp
# конец варп
# search_mob
# Idet_boi
# F1
# idet_boi= 1
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 9
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# Не найден gurirsta
# Smena_lokacii- 10
# varp
# конец варп
# search_mob
# Idet_boi
# F1
# idet_boi= 1
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 10
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# Не найден gurirsta
# Smena_lokacii- 11
# varp
# конец варп
# search_mob
# Idet_boi
# F1
# idet_boi= 1
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 11
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# attack.цикл= 36
# attack.цикл= 37
# attack.цикл= 38
# attack.цикл= 39
# attack.цикл= 40
# attack.цикл= 41
# attack.цикл= 42
# attack.цикл= 43
# attack.цикл= 44
# attack.цикл= 45
# attack.цикл= 46
# attack.цикл= 47
# attack.цикл= 48
# attack.цикл= 49
# attack.цикл= 50
# attack.цикл= 51
# attack.цикл= 52
# attack.цикл= 53
# attack.цикл= 54
# attack.цикл= 55
# attack.цикл= 56
# attack.цикл= 57
# attack.цикл= 58
# attack.цикл= 59
# attack.цикл= 60
# attack.цикл= 61
# attack.цикл= 62
# attack.цикл= 63
# attack.цикл= 64
# attack.цикл= 65
# attack.цикл= 66
# attack.цикл= 67
# attack.цикл= 68
# attack.цикл= 69
# attack.цикл= 70
# attack.цикл= 71
# attack.цикл= 72
# attack.цикл= 73
# attack.цикл= 74
# attack.цикл= 75
# attack.цикл= 76
# attack.цикл= 77
# attack.цикл= 78
# attack.цикл= 79
# attack.цикл= 80
# attack.цикл= 81
# attack.цикл= 82
# attack.цикл= 83
# attack.цикл= 84
# attack.цикл= 85
# attack.цикл= 86
# attack.цикл= 87
# attack.цикл= 88
# attack.цикл= 89
# attack.цикл= 90
# attack.цикл= 91
# attack.цикл= 92
# attack.цикл= 93
# attack.цикл= 94
# attack.цикл= 95
# attack.цикл= 96
# attack.цикл= 97
# attack.цикл= 98
# attack.цикл= 99
# attack.цикл= 100
# attack.цикл= 101
# attack.цикл= 102
# attack.цикл= 103
# attack.цикл= 104
# attack.цикл= 105
# attack.цикл= 106
# attack.цикл= 107
# attack.цикл= 108
# attack.цикл= 109
# attack.цикл= 110
# attack.цикл= 111
# attack.цикл= 112
# attack.цикл= 113
# attack.цикл= 114
# attack.цикл= 115
# attack.цикл= 116
# attack.цикл= 117
# attack.цикл= 118
# attack.цикл= 119
# attack.цикл= 120
# attack.цикл= 121
# attack.цикл= 122
# attack.цикл= 123
# attack.цикл= 124
# attack.цикл= 125
# attack.цикл= 126
# attack.цикл= 127
# attack.цикл= 128
# attack.цикл= 129
# attack.цикл= 130
# attack.цикл= 131
# attack.цикл= 132
# attack.цикл= 133
# attack.цикл= 134
# attack.цикл= 135
# attack.цикл= 136
# attack.цикл= 137
# attack.цикл= 138
# attack.цикл= 139
# attack.цикл= 140
# attack.цикл= 141
# attack.цикл= 142
# attack.цикл= 143
# attack.цикл= 144
# attack.цикл= 145
# attack.цикл= 146
# attack.цикл= 147
# attack.цикл= 148
# attack.цикл= 149
# attack.цикл= 150
# attack.цикл= 151
# attack.цикл= 152
# attack.цикл= 153
# attack.цикл= 154
# attack.цикл= 155
# attack.цикл= 156
# attack.цикл= 157
# attack.цикл= 158
# attack.цикл= 159
# attack.цикл= 160
# attack.цикл= 161
# attack.цикл= 162
# attack.цикл= 163
# attack.цикл= 164
# attack.цикл= 165
# attack.цикл= 166
# attack.цикл= 167
# attack.цикл= 168
# attack.цикл= 169
# attack.цикл= 170
# attack.цикл= 171
# attack.цикл= 172
# attack.цикл= 173
# attack.цикл= 174
# attack.цикл= 175
# attack.цикл= 176
# attack.цикл= 177
# attack.цикл= 178
# attack.цикл= 179
# attack.цикл= 180
# attack.цикл= 181
# attack.цикл= 182
# attack.цикл= 183
# attack.цикл= 184
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# новый цикл 12
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# Не найден gurirsta
# Smena_lokacii- 13
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 13
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# Не найден gurirsta
# Smena_lokacii- 14
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# rabota_oruzhiya - stop
# F1
# idet_boi= 3
# attack
# attack.цикл= 1
# rabota_oruzhiya - stop
# F1
# idet_boi= 4
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 5
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# attack.цикл= 36
# attack.цикл= 37
# attack.цикл= 38
# attack.цикл= 39
# attack.цикл= 40
# attack.цикл= 41
# rabota_oruzhiya - stop
# F1
# idet_boi= 6
# mob1=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# rabota_oruzhiya - stop
# F1
# idet_boi= 7
# mob1=нет
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# attack.цикл= 36
# attack.цикл= 37
# attack.цикл= 38
# attack.цикл= 39
# attack.цикл= 40
# rabota_oruzhiya - stop
# F1
# idet_boi= 8
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 9
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 10
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# rabota_oruzhiya - stop
# F1
# idet_boi= 11
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# rabota_oruzhiya - stop
# F1
# новый цикл 14
# RUN
# udalenie_hound
# hound не обнаружен
# search_gurista
# click_R
# click
# varp
# конец варп
# search_mob
# click_R
# click
# Idet_boi
# F1
# idet_boi= 1
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# attack.цикл= 36
# rabota_oruzhiya - stop
# F1
# idet_boi= 2
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# attack.цикл= 36
# attack.цикл= 37
# attack.цикл= 38
# attack.цикл= 39
# attack.цикл= 40
# attack.цикл= 41
# rabota_oruzhiya - stop
# F1
# idet_boi= 3
# attack
# attack.цикл= 1
# attack.цикл= 2
# rabota_oruzhiya - stop
# F1
# idet_boi= 4
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# attack.цикл= 36
# attack.цикл= 37
# attack.цикл= 38
# attack.цикл= 39
# attack.цикл= 40
# attack.цикл= 41
# attack.цикл= 42
# rabota_oruzhiya - stop
# F1
# idet_boi= 5
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 6
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# attack.цикл= 5
# attack.цикл= 6
# attack.цикл= 7
# attack.цикл= 8
# attack.цикл= 9
# attack.цикл= 10
# attack.цикл= 11
# attack.цикл= 12
# attack.цикл= 13
# attack.цикл= 14
# attack.цикл= 15
# attack.цикл= 16
# attack.цикл= 17
# attack.цикл= 18
# attack.цикл= 19
# attack.цикл= 20
# attack.цикл= 21
# attack.цикл= 22
# attack.цикл= 23
# attack.цикл= 24
# attack.цикл= 25
# attack.цикл= 26
# attack.цикл= 27
# attack.цикл= 28
# attack.цикл= 29
# attack.цикл= 30
# attack.цикл= 31
# attack.цикл= 32
# attack.цикл= 33
# attack.цикл= 34
# attack.цикл= 35
# attack.цикл= 36
# attack.цикл= 37
# attack.цикл= 38
# attack.цикл= 39
# attack.цикл= 40
# attack.цикл= 41
# attack.цикл= 42
# rabota_oruzhiya - stop
# F1
# idet_boi= 7
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 8
# attack
# attack.цикл= 1
# attack.цикл= 2
# attack.цикл= 3
# attack.цикл= 4
# rabota_oruzhiya - stop
# F1
# idet_boi= 9
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 10
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 11
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 12
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 13
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 14
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 15
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 16
# attack
# rabota_oruzhiya - stop
# F1
# idet_boi= 17
# attack
# rabota_oruzhiya - stop
# F1
# отварп на Safe_buka
# safe_buka.png
# click_R
# click
# idet_boi= 18
# mob1=нет
# mob2=нет
# mob3=нет
# attack
# блокировка не найдена
# отварп на Safe_buka
# safe_buka.png
# click_R
# click
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-a707696131fd> in <module>
#     251     print("новый цикл",i)
#     252     i+=1
# --> 253     RUN(i)
#     254
#     255
#
# <ipython-input-45-a707696131fd> in RUN(i)
#     244     search_mob()
#     245     pause_random(0.8)
# --> 246     Idet_boi()
#     247
#     248 i=0
#
# <ipython-input-45-a707696131fd> in Idet_boi()
#     225                 pause_random(0.8)
#     226                 click(x,y,0.1)
# --> 227                 pause_random(60)
#     228             else:
#     229                 print(" нет сейф-буки!")
#
# <ipython-input-45-a707696131fd> in pause_random(x)
#      48
#      49 def pause_random(x):
# ---> 50     time.sleep(random.uniform(x*1.1,x*2))
#      51
#      52 def search_gurista(i):
#
# KeyboardInterrupt:

# %%
"""
предустановки игры:
разерешение 1600*1900 (125%)
нахождение:правый верхний угол
2222,980 / 3840,760
region=(2222,60,3840,980)
лево верх = 2200,50,500,450
лево низ = 2200,500,500,400
сред верх = 2900,330,150,300
сред низ = 2900,600,200,350



"""
import pyautogui    #работа с картинками
import time         #таймеры
import win32api     #для управления мышью, pyautohui не всегда срабатывает клик
import win32con     #для управления мышью, pyautohui не всегда срабатывает клик
import win32com.client     #для управления нажатием HOME
import pyttsx3      #звук
import os           #переход в спящий режим
import pytesseract as tess  #расознование текста
tess.pytesseract.tesseract_cmd  = r'C:\Program Files\Tesseract-OCR\tesseract.exe' #расознование текста
#tess.pytesseract.tesseract_cmd  = r'C:\Program Files\Tesseract-OCR\4.0-with-LSTM\tesseract.exe'
from PIL import Image #расознование текста
import re          #парсинг цен
import pyperclip   #работа с буфером
import random      #рандом
import pyttsx3      #звук
engine = pyttsx3.init() #звук

""" Change_price
функция изменеия стоимости.
работает при открытом окне "торговая система"
В секторе "Продавцы"(Торговая система) находим цена, которая есть на расстоянии "Станция".
Если строка "Станция" не имеет синего фона - то продолжать, иначе конец функции
переводим в цифру сумму в столбике "Цена" 
в окне "заказы в торговой системе"
выделяем изначальный товара в "продажа"(заказы в торговой система)  - повой мышкой -
изменить ордер 
ввод текста (пока не понятно как, или через буфер обмена, или по цифрам)
"""

def click(x,y,t): # просто клик мышки по координатам ЛЕВОЙ
    print("click")
    win32api.SetCursorPos((x,y))
    time.sleep(0.1)
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTDOWN,x,y,0,0)
    time.sleep(t)
    win32api.mouse_event(win32con.MOUSEEVENTF_LEFTUP,x,y,0,0)
    
def click_R(x,y,t): #  клик мышки по координатам ПРАВОЙ кнопкой
    print("click_R")
    win32api.SetCursorPos((x,y))
    time.sleep(0.1)
    win32api.mouse_event(win32con.MOUSEEVENTF_RIGHTDOWN,x,y,0,0)
    time.sleep(t)
    win32api.mouse_event(win32con.MOUSEEVENTF_RIGHTUP,x,y,0,0)

def LUP(): #выход на 1 позицию
    print("LUP")
    print("поиск продажа")
    #Проверяем наличие вкладки"Торговая система"
    pict = pyautogui.locateOnScreen('prodazha.png', confidence=0.85,region=(2222,60,1000,980)) #без левого столба "заказы в торг сист"
    if pict==None:
        print("не найдена картинка Торговая система")
    else:
        pause_random(0.3)
        x,y=pyautogui.center(pict)
        y=y+100
        click(x,y,0.1)
        pause_random(0.3)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{HOME}")
        
def B_LUP(): #выход на 1 позицию
    print("B_LUP")
    print("поиск покупка")
    #Проверяем наличие вкладки"Торговая система"
    pict = pyautogui.locateOnScreen('pokupka.png', confidence=0.9,region=(2200,50,1000,1000)) #без левого столба "заказы в торг сист"
    if pict==None:
        print("не найдена картинка Покупка")
    else:
        pause_random(0.3)
        x,y=pyautogui.center(pict)
        y=y+100
        click(x,y,0.1)
        pause_random(0.3)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{HOME}")
        
def menu_prodazha():
    print("menu_prodazha")
    pict = pyautogui.locateOnScreen('i.png', confidence=0.9,region=(2200,50,500,450))
    if pict==None:
        print("не найдена картинка i")
    else:
        pause_random(0.2)
        x,y=pyautogui.center(pict)
        x=x-50
        click(x,y,0.1)
        time.sleep(0.2)
        click(x,y,0.1)
        click(x,y,0.1) #тройной клик по позиции слева
        analiz_cen(x,y)
        
def B_menu_prodazha():
    print("B_menu_prodazha")
    pict = pyautogui.locateOnScreen('i.png', confidence=0.9,region=(2200,500,500,400))
    if pict==None:
        print("не найдена картинка i")
    else:
        pause_random(0.1)
        x,y=pyautogui.center(pict)
        x=x-50
        click(x,y,0.1)
        time.sleep(0.2)
        click(x,y,0.1)
        click(x,y,0.1) #тройной клик по позиции слева
        B_analiz_cen(x,y) #возврат координат левый столб
    
def menu_prodazha_blue():
    print("menu_prodazha_blue")
    pause_random(0.4)
    time.sleep(0.1)
    pict = pyautogui.locateOnScreen('i_blue.png', confidence=0.90,region=(2200,50,500,450))
    if pict==None:
        print("не найдена картинка i_blue")
    else:
        pause_random(0.1)
        x,y=pyautogui.center(pict)
        x=x-50
        y=y+10
        click(x,y,0.1)
        time.sleep(0.2)
        click(x,y,0.1)
        click(x,y,0.1) #тройной клик по позиции слева
        analiz_cen(x,y)
        
def B_menu_prodazha_blue():
    print("menu_prodazha_blue")
    pause_random(0.4)
    time.sleep(0.1)
    pict = pyautogui.locateOnScreen('i_blue.png', confidence=0.90,region=(2200,500,500,400))
    if pict==None:
        print("не найдена картинка i_blue")
    else:
        pause_random(0.1)
        x,y=pyautogui.center(pict)
        x=x-50
        y=y+10
        click(x,y,0.1)
        click(x,y,0.1)
        time.sleep(0.1)
        click(x,y,0.1) #тройной клик по позиции слева
        B_analiz_cen(x,y)
    
def analiz_cen(x,y):
    print("analiz_cen")
    pause_random(0.9)       
    pict = pyautogui.locateOnScreen('Stancia_blue_black.png', confidence=0.99,region=(2850,330,150,300))
    pict2 = pyautogui.locateOnScreen('Stancia_blue.png', confidence=0.99,region=(2850,330,150,300))
    if pict!=None or (pict==None and pict2==None):    #если синяя на 2 месте или вообще нет
        print('меняем цену:')
        pict = pyautogui.locateOnScreen('Stancia_black.png', confidence=0.9,region=(2850,330,150,300)) #сред низ
        if pict==None:
            print("Stancia_black не найдена")
        else:
            x1,y1=pyautogui.center(pict)
            pause_random(0.3)
            click(x1,y1,0.2)
            time.sleep(0.5)
            win32api.keybd_event (win32con.VK_LCONTROL,1)
            time.sleep(0.3)
            shell = win32com.client.Dispatch("WScript.Shell")
            time.sleep(0.3)
            shell.SendKeys("{C}")
            pause_random(0.4)
            shell.SendKeys("^")
            pause_random(0.2)
            shell.SendKeys("^")
            pause_random(0.2)
            text=pyperclip.paste()
            pause_random(0.3)
            print ("цена скопирована")
            text = re.sub(r'Станция	','', text)
            text = text.replace(u'\xa0', u' ')
            text = re.sub(r' ','', text)
            text = re.sub(r'[xa]','', text)
            print (text)
            text = re.sub(r'ISK[^`]{,1000}','', text)
            #конвертация с проверкой
            try:
                a=float(text)
            except ValueError:
                print('Ошибка. скопирован текст')
                a=0
            else:         
                time.sleep(0.1)
                a=a-0.01
                print(a)   # минимальная цена продажи (FLOAT)      - определиться или буфер или переменная!!!
                pyperclip.copy (a)
                change_price(x,y)
    else:
        print("Изменение цен не требуется")
        click(x,y,0.1)
        
def B_analiz_cen(x,y):
    print("B_analiz_cen")
    pause_random(0.9)       
    pict = pyautogui.locateOnScreen('Stancia_green_black.png', confidence=0.99,region=(2850,600,200,350))
    pict2 = pyautogui.locateOnScreen('Stancia_blue.png', confidence=0.99,region=(2850,600,200,350))
    if pict!=None or (pict==None and pict2==None):    #если синяя на 2 месте или вообще нет
        print('меняем цену:')
        pict = pyautogui.locateOnScreen('Stancia_blue.png', confidence=0.9,region=(2850,600,200,350)) #сред низ
        if pict==None:
            print("Stancia_blue не найдена")
        else:
            x1,y1=pyautogui.center(pict)
            pause_random(0.3)
            click(x1,y1,0.2)
            time.sleep(0.5)
            win32api.keybd_event (win32con.VK_LCONTROL,1)
            time.sleep(0.3)
            shell = win32com.client.Dispatch("WScript.Shell")
            time.sleep(0.3)
            shell.SendKeys("{C}")
            pause_random(0.4)
            shell.SendKeys("^")
            pause_random(0.2)
            shell.SendKeys("^")
            pause_random(0.2)
            text=pyperclip.paste()
            pause_random(0.3)
            print ("цена скопирована")
            text = re.sub(r'Станция	','', text)
            text = text.replace(u'\xa0', u' ')
            text = re.sub(r' ','', text)
            text = re.sub(r'[xa]','', text)
            print (text)
            text = re.sub(r'ISK[^`]{,1000}','', text)
            #конвертация с проверкой
            try:
                a=float(text)
            except ValueError:
                print('Ошибка. скопирован текст')
                a=0
            else:         
                time.sleep(0.1)
                a=a+0.011
                print(a)   # минимальная цена продажи (FLOAT)      - определиться или буфер или переменная!!!
                pyperclip.copy (a)
                B_change_price(x,y)
    else:
        print("Изменение цен не требуется")
        click(x,y,0.1)

def change_price(x,y):
    print("change_price")
    pause_random(0.2)
    click_R(x,y,0.2)
    time.sleep(0.4)
    pict = pyautogui.locateOnScreen('izmenit_order.png', confidence=0.95,region=(2200,50,800,600)) #без левого
    if pict==None:
        print("ОШИБКА! не найдена картинка измененить ордер")
    else:
        pause_random(0.1)
        click (x+20,y+15,0.2) #в подменю "изменить цену"
        #прожимаем Del
        win32api.keybd_event (win32con.VK_LCONTROL,1)
        pause_random(0.3)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{V}")
        pause_random(0.3)
        shell.SendKeys("^")
        pause_random(0.3)
        shell.SendKeys("{ENTER}")
        pause_random(0.3)
        pict = pyautogui.locateOnScreen('da.png', confidence=0.9,region=(2222,60,1000,1000))
        if pict:
            x1,y1=pyautogui.center(pict)
            time.sleep(0.5)
            click(x1,y1,0.2)
        else:
            print("не найдена ДА")
            
def B_change_price(x,y):
    print("B_сhange_price")
    pause_random(0.2)
    click_R(x,y,0.2)
    time.sleep(0.5)
    pict = pyautogui.locateOnScreen('izmenit_order.png', confidence=0.93,region=(2200,500,700,400)) #без левого
    if pict==None:
        print("ОШИБКА! не найдена картинка измененить ордер")   
    else:
        pause_random(0.1)
        x1,y1=pyautogui.center(pict)
        click (x1,y1,0.2) #в подменю "изменить цену"
        #прожимаем Del
        win32api.keybd_event (win32con.VK_LCONTROL,1)
        pause_random(0.3)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{V}")
        pause_random(0.3)
        shell.SendKeys("^")
        pause_random(0.3)
        shell.SendKeys("{ENTER}")
        pause_random(0.3)
        pict = pyautogui.locateOnScreen('da.png', confidence=0.9,region=(2222,60,1000,1000))
        if pict:
            x1,y1=pyautogui.center(pict)
            time.sleep(0.5)
            click(x1,y1,0.2)
        else:
            print("не найдена ДА")

def run():
    print("Start_SELL >>>>>>>>>>>>>>>>>>>")
    i=0
    pause_random(0.5)
    pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.95,region=(2200,50,500,500))
    LUP()
    while pict==None: 
        pause_random(0.1)
        print('Новый цикл ====')
        if i==0:
            menu_prodazha()
        else:
            menu_prodazha_blue()
        i=+1
        pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.95,region=(2200,50,500,500))
        time.sleep(0.1)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{DOWN}")
    pause_random(0.2)    
    shell = win32com.client.Dispatch("WScript.Shell")
    shell.SendKeys("{HOME}")

def B_run():
    print("Start_BUY >>>>>>>>>>>>>>>>>>>")
    i=0
    pause_random(0.5)
    pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.95,region=(2200,600,500,400)) #лев низ
    B_LUP()
    while pict==None:
        pause_random(0.1)
        if i==0:
            B_menu_prodazha()
        else:
            B_menu_prodazha_blue()
        i=+1
        pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.95,region=(2200,600,500,400)) #лев низ
        time.sleep(0.1)
        shell = win32com.client.Dispatch("WScript.Shell")
        shell.SendKeys("{DOWN}")
    pause_random(0.2)    
    shell = win32com.client.Dispatch("WScript.Shell")
    shell.SendKeys("{HOME}")
    
def pause_random(x):
    time.sleep(random.uniform(x*1.3,x*2.5))

time.sleep(5)
i=0    
for i in range(0,100):   
    print ("новый цикл ================================= ",i)
    run()
    B_run()
    engine.say('Проверка закончена')
    engine.runAndWait()
    pause_random(2)
print("END")
# Out:
# новый цикл =================================  0
# Start_SELL >>>>>>>>>>>>>>>>>>>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-42-37a8a0d1f391> in <module>
#     365 for i in range(0,100):
#     366     print ("новый цикл ================================= ",i)
# --> 367     run()
#     368     B_run()
#     369     engine.say('Проверка закончена')
#
# <ipython-input-42-37a8a0d1f391> in run()
#     319     i=0
#     320     pause_random(0.5)
# --> 321     pict = pyautogui.locateOnScreen('lup_end.png', confidence=0.95,region=(2200,50,500,500))
#     322     LUP()
#     323     while pict==None:
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pyscreeze\__init__.py in locateOnScreen(image, minSearchTime, **kwargs)
#     356         try:
#     357             screenshotIm = screenshot(region=None) # the locateAll() function must handle cropping to return accurate coordinates, so don't pass a region here.
# --> 358             retVal = locate(image, screenshotIm, **kwargs)
#     359             try:
#     360                 screenshotIm.fp.close()
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pyscreeze\__init__.py in locate(needleImage, haystackImage, **kwargs)
#     336     # Note: The gymnastics in this function is because we want to make sure to exhaust the iterator so that the needle and haystack files are closed in locateAll.
#     337     kwargs['limit'] = 1
# --> 338     points = tuple(locateAll(needleImage, haystackImage, **kwargs))
#     339     if len(points) > 0:
#     340         return points[0]
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pyscreeze\__init__.py in _locateAll_opencv(needleImage, haystackImage, grayscale, limit, region, step, confidence)
#     193     confidence = float(confidence)
#     194
# --> 195     needleImage = _load_cv2(needleImage, grayscale)
#     196     needleHeight, needleWidth = needleImage.shape[:2]
#     197     haystackImage = _load_cv2(haystackImage, grayscale)
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pyscreeze\__init__.py in _load_cv2(img, grayscale)
#     158             raise IOError("Failed to read %s because file is missing, "
#     159                           "has improper permissions, or is an "
# --> 160                           "unsupported or invalid format" % img)
#     161     elif isinstance(img, numpy.ndarray):
#     162         # don't try to convert an already-gray image to gray
#
# OSError: Failed to read lup_end.png because file is missing, has improper permissions, or is an unsupported or invalid format

# %%
import pyttsx3      #звук
engine = pyttsx3.init() #звук
engine.say('Проверка закончена')
engine.runAndWait()

# %%
time.sleep(1)
def analiz_cen():
    print("B_analiz_cen")
    pause_random(0.9)       
    pict = pyautogui.locateOnScreen('Stancia_green_black.png', confidence=0.99,region=(2850,600,200,350))
    pict2 = pyautogui.locateOnScreen('Stancia_blue.png', confidence=0.99,region=(2850,600,200,350))
    if pict!=None or (pict==None and pict2==None):    #если синяя на 2 месте или вообще нет
        print('меняем цену:')
        pict = pyautogui.locateOnScreen('Stancia_blue.png', confidence=0.9,region=(2850,600,200,350)) #сред низ
        if pict==None:
            print("Stancia_blue не найдена")
        else:
            print("блок замены")
    else:
        print("Изменение цен не требуется")

analiz_cen()

# %%
import random
print(random.uniform(0.5, 1))
pause_random

# %%
#буфер обмена
>>> import pyperclip
>>> pyperclip.copy('The text to be copied to the clipboard.')
>>> pyperclip.paste()

# %%
#
import pytesseract #расознование текста
C:\Program Files\Tesseract-OCR
from PIL import Image
from pytesseract import image_to_string
#k=pytesseract.image_to_string('1.png')
#print(k)
print pytesseract.image_to_string(Image.open('1.png'))

# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

def ocr_core(filename):
    """
    This function will handle the core OCR processing of images.
    """
    text = pytesseract.image_to_string(Image.open(filename))  # We'll use Pillow's Image class to open the image and pytesseract to detect the string in the image
    return text

print(ocr_core('2.png'))

# %%
import pytesseract as tess
tess.pytesseract.tesseract_cmd  = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
from PIL import Image

img = Image.open('11.png')
text = tess.image_to_string(img)
print(text)

# %%
#https://api.evemarketer.com/ec/marketstat/json?typeid=1000
#https://api.evemarketer.com/ec/marketstat?typeid=631&regionlimit=10000002
import requests

accept= "application/json"
response = requests.get(https://api.evemarketer.com/ec/marketstat/json) # get-запрос
print(response.text) # вывод содержимого страницы

# %%
time.sleep(2)
im = pyautogui.screenshot(region=(0,0, 1600, 1600))
time.sleep(1)
im2 = pyautogui.screenshot(region=(0,0, 1600, 1600))
if im==im2:
    print('ravno')
else:
    print("net")
